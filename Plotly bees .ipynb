# %%
import pandas as pd
import plotly.graph_objects as go
from dash import Dash, dcc, html, Input, Output 
from plotly.subplots import make_subplots

# %%
link = r"C:\Users\Me\Desktop\PYTHON\intro_bees.csv"
df = pd.read_csv(link)
df = df.loc[df.Year == 2018]
df = df.groupby(['State', 'Affected by', 'state_code'])[['Pct of Colonies Impacted']].mean()
df.reset_index(inplace=True)
df.head(10)
# Out:
#      State        Affected by state_code  Pct of Colonies Impacted
# 0  Alabama            Disease         AL                     1.300
# 1  Alabama              Other         AL                     7.300
# 2  Alabama         Pesticides         AL                    11.350
# 3  Alabama  Pests_excl_Varroa         AL                    36.850
# 4  Alabama            Unknown         AL                     5.225
# 5  Alabama       Varroa_mites         AL                    38.125
# 6  Arizona            Disease         AZ                    11.250
# 7  Arizona              Other         AZ                    11.075
# 8  Arizona         Pesticides         AZ                     4.975
# 9  Arizona  Pests_excl_Varroa         AZ                     5.525

# %%
app = Dash(__name__)

app.layout = html.Div([
    
    html.H2('Bees colonies analysis'),
    
    # dropdown
    html.P("Select state:"),
    dcc.Dropdown(
        id='state', 
        options=df["State"].unique(),
        value = None
    ),
    dcc.Dropdown(
        id='reason', 
        options=df["Affected by"].unique(),
        value = None
    ),
    
    # graph
    dcc.Graph(id="graph"),
        
])


@app.callback(
    Output("graph", "figure"), 
    Input("state", "value"),
    Input("reason", "value"),
)

def display_choropleth(state, reason):
    
    # create subset indexes based on selection
    if reason is not None:
        idx1 = df['Affected by'] == reason
    else:
        idx1 = ~df['Affected by'].isna()
    if state is not None:
        idx2 = df['State'] == state
    else:
        idx2 = ~df['State'].isna()
    
    # left graph
    data = df.loc[idx1 & idx2,:].groupby('state_code')['Pct of Colonies Impacted'].sum()
    fig = go.Figure(go.Choropleth(
                                    z=data,
                                    locationmode='USA-states',
                                    locations=data.index,
                                    )
    )
    
    # general settings
    fig.update_layout(geo_scope='usa', title='Map')
    return fig

if __name__ == "__main__":
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Dec/2023 16:19:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:19:19] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:19:19] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:19:19] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Dec/2023 16:19:19] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Dec/2023 16:19:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:19:19] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Dec/2023 16:19:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:19:20] "GET /_favicon.ico?v=2.7.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:19:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:19:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:19:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:19:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:36:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:36:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:36:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:36:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:36:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:36:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:36:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:36:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:38:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:38:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:38:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:38:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:38:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:38:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:38:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:38:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:38:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:38:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:39:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:39:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:39:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:39:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:39:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:39:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:39:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:39:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:39:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:40:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:40:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:40:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:40:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:40:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:40:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:40:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:40:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:40:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:42:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:44:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:44:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:44:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:44:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:44:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Dec/2023 16:44:48] "POST /_dash-update-component HTTP/1.1" 200 -
